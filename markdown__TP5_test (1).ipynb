# %% [markdown]
# # Rapport de Test : Mise en œuvre de Services Réseau sur Machines Virtuelles
#
# ## 1. Présentation de la Maquette Globale
# L'objectif de cette séance est de mettre en œuvre l'architecture réseau en utilisant uniquement des machines virtuelles (VM). Voici le schéma de l'infrastructure réseau utilisée :
#
# ![image.png](attachment:image.png)
#
# ### Détails des VLANs :
# * **VLAN 10 (ADMN) :** Administration et serveurs.
# * **VLAN 20 (PERSONNEL) :** Utilisateurs du personnel.
# * **VLAN 30 (PRODUCTION) :** Secteur production.
# * **VLAN 40 (VIDEO) :** Flux vidéo.
#
# ---

# %% [markdown]
# ## 2. Tests de Connectivité (ICMP)
# Avant de tester les services applicatifs, nous avons validé la communication entre les différents segments du réseau (routage inter-VLAN).
#
# **Résultats des tests de Ping :**
# ![image.png](attachment:image.png)
#
# On constate que les communications entre les PC des différents VLANs sont opérationnelles (Status: Successful).

# %% [markdown]
# ## 3. Mise en œuvre des Services (Web, DNS, DHCP)
#
# ### A. Serveur Web
# Un serveur Web a été installé sur une machine virtuelle. Nous avons vérifié l'accessibilité du service.
#
# ### B. Serveur DNS et DHCP (dnsmasq)
# Suivant la documentation fournie (linuxtricks), nous avons configuré `dnsmasq` pour :
# 1. Distribuer les adresses IP automatiquement aux clients.
# 2. Résoudre les noms de domaine internes.
# ![image.png](attachment:image.png)
# ---
